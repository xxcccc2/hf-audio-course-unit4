# %% [markdown]
# # Hugging Face Audio Course Unit 4
#
# Run this notebook in Google Colab with a GPU runtime. Replace the repository URL before running the clone cell.

# %%
REPO_URL = "https://github.com/xxcccc2/hf-audio-course-unit4"
REPO_DIR = "/content/unit4-repo"

# %%
# !rm -rf $REPO_DIR
# !git clone $REPO_URL $REPO_DIR
# %cd $REPO_DIR
# Out:
# Cloning into '/content/unit4-repo'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 57 (delta 14), reused 56 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 15.76 KiB | 1.75 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/unit4-repo

# %%
# !nvidia-smi
# Out:
# Wed Jul  1 09:36:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install -q -r requirements-colab.txt
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# !python src/train.py --output-dir artifacts/distilhubert-gtzan
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data/genres.tar.gz: 100% 1.23G/1.23G [00:08<00:00, 137MB/s]
# Generating train split: 999 examples [00:00, 7807.93 examples/s]
# preprocessor_config.json: 100% 214/214 [00:00<00:00, 1.10MB/s]
# Map: 100% 899/899 [01:27<00:00, 10.26 examples/s]
# Map: 100% 100/100 [00:26<00:00,  3.75 examples/s]
# config.json: 100% 1.30k/1.30k [00:00<00:00, 4.57MB/s]
# model.safetensors: 100% 94.0M/94.0M [00:02<00:00, 38.1MB/s]
# Loading weights: 100% 49/49 [00:00<00:00, 6199.54it/s]
# [transformers] HubertForSequenceClassification LOAD REPORT from: ntu-spml/distilhubert
# Key               | Status  |
# ------------------+---------+-
# classifier.weight | MISSING |
# classifier.bias   | MISSING |
# projector.bias    | MISSING |
# projector.weight  | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
#   3% 15/570 [03:01<1:49:39, 11.85s/it]

# %%
# Optional after login:
# from huggingface_hub import notebook_login
# notebook_login()
# !python src/train.py --output-dir artifacts/distilhubert-gtzan --push-to-hub --hub-model-id your-username/distilhubert-finetuned-gtzan

# %%
# Optional demo:
# !python src/app.py --model artifacts/distilhubert-gtzan
