# %% [markdown]
# # Hugging Face Audio Course Unit 4
#
# Run this notebook in Google Colab with a GPU runtime. Replace the repository URL before running the clone cell.
#
# This notebook defaults to an AST recipe aimed at the Unit 4 hands-on target of 87%+ accuracy on GTZAN.
# The training command mirrors a public GTZAN AST recipe that reported 0.89 accuracy.

# %%
REPO_URL = "https://github.com/xxcccc2/hf-audio-course-unit4.git"
REPO_DIR = "/content/unit4-repo"

# %%
# %cd /content
# !rm -rf $REPO_DIR
# !git clone $REPO_URL $REPO_DIR
# %cd $REPO_DIR

# %%
# !nvidia-smi

# %%
# !pip install -q -r requirements-colab.txt

# %%
# !python src/train.py --model-id MIT/ast-finetuned-audioset-10-10-0.4593 --output-dir artifacts/ast-gtzan --per-device-train-batch-size 2 --per-device-eval-batch-size 2 --gradient-accumulation-steps 4 --learning-rate 5e-5 --num-train-epochs 25 --seed 42

# %%
# Optional after login:
# from huggingface_hub import notebook_login
# notebook_login()
# !python src/train.py --model-id MIT/ast-finetuned-audioset-10-10-0.4593 --output-dir artifacts/ast-gtzan --per-device-train-batch-size 2 --per-device-eval-batch-size 2 --gradient-accumulation-steps 4 --learning-rate 5e-5 --num-train-epochs 25 --seed 42 --push-to-hub --hub-model-id your-username/ast-finetuned-gtzan

# %%
# Optional demo:
# !python src/app.py --model artifacts/ast-gtzan
